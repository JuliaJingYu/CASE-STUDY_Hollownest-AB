# %% [markdown]
# __NOTE:__
#
# 1) This document is arranged in an order following the __Case_description__
#
# 2) Section A OVERVIEW is available in the __Case_description__
#
# 3) This document starts from SECTION B  DATA PREPARATION as per __Case_desription__

# %%
#Import libraries 
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import datetime
# %matplotlib inline

# %% [markdown]
# # SECTION B     DATA PREPARATION
# ##  B.2         Data pre-processing

# %% [markdown]
# ### B.2.1   Item Data

# %%
#read in items data
items = pd.read_csv('Item.csv', sep = ',')

# %%
items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2188800 entries, 0 to 2188799
# Data columns (total 6 columns):
# ITEM             int64
# CATEGORY         object
# COLOR            object
# SUPLID           object
# PURCHASEPRICE    float64
# SALEPRICE        int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 100.2+ MB

# %%
items.PURCHASEPRICE.isnull().any()
# Out:
# False

# %% [markdown]
# #### Data-type contraints: cleaning, verifying and reporting

# %%
# Change dtype of saleprice to decimal 
before = type(items.SALEPRICE[0])
items.SALEPRICE = items.SALEPRICE.astype('float64')
after = type(items.SALEPRICE[0])
before
after
# Out:
# numpy.float64

# %%
# check the size of the dataframe 
items.shape
# Out:
# (2188800, 6)

# %%
# check the first 5 rows of the items dataframe 
items.head()
# Out:
#      ITEM CATEGORY   COLOR   SUPLID  PURCHASEPRICE  SALEPRICE
# 0  127521  PAJAMAS    PINK  41560EE        1867.09     2800.0
# 1  151662    SOCKS    GOLD  16091ZZ        1862.08     2050.0
# 2  453756     COAT    GOLD  11370LL         914.81     1370.0
# 3  434386  PAJAMAS  SILVER  41560EE        1913.00     1430.0
# 4  422712    DRESS  SILVER  48094JJ         851.43      940.0

# %%
# check data types of the columns based on the data dictionary 
items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2188800 entries, 0 to 2188799
# Data columns (total 6 columns):
# ITEM             int64
# CATEGORY         object
# COLOR            object
# SUPLID           object
# PURCHASEPRICE    float64
# SALEPRICE        float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 100.2+ MB

# %% [markdown]
# ##### Reporting: As seen above, the currently stored items data type meets the data-type contraints requirments.

# %% [markdown]
# ### B.2.2    Customer Data

# %%
#read in customer data
customers = pd.read_csv('CustomerData.txt', sep='|')
customers
# Out:
#      USERID GENDER         DOB               COUNTRY              EDUCATION  \
# 0     39060      F  1982-09-18              Ethiopia
# 1     26050      M  1988-11-22  United Arab Emirates
# 2     48580      M  1975-12-06            Martinique               Bachelor
# 3     40220      F  1984-11-16               Germany                 Master
# 4     25160      M  1977-12-05            Madagascar                 Master
# 5     37700      M  1972-12-19                Guinea            High school
# 6     25080      M  1987-03-03                 Japan               Bachelor
# 7     34140      N  1972-06-11               Algeria            High school
# 8     27260      F  2000-12-28           Puerto Rico            High school
# 9     37480      M  1966-04-09            Antarctica
# 10    19140      F  1994-06-14               Senegal                 Master
# 11    17410      F  1978-03-30                France                 Master
# 12    20880      F  1978-03-20                 Chile                 Master
# 13    49710      F  1968-09-12                 Japan                 Master
# 14    27760      F  1980-02-23             Gibraltar
# 15    48100      F  1973-04-25               Reunion                 Master
# 16    40240      F  1990-07-01            Martinique
# 17    29220      F  1993-09-26               Morocco            High school
# 18    38130      F  1985-06-09                Mexico               Bachelor
# 19    12670      F  1982-05-03               Uruguay            High school
# 20    48550      M  1975-02-19                France               Bachelor
# 21    48520      M  1983-02-20             Gibraltar            High school
# 22    43290      F  1984-08-16              Guernsey            High school
# 23    27120      F  1989-12-15             Macedonia            High school
# 24    17820      F  1980-07-01               Liberia
# 25    31310      N  1971-09-06                Jordan
# 26    13240      F  1993-12-30                 Malta               Bachelor
# 27    42330      F  1993-07-27               Bahamas               Bachelor
# 28    46530      F  1967-03-24                 Japan
# 29    40380      M  1971-01-11             Greenland               Bachelor
# ..      ...    ...         ...                   ...                    ...
# 544   45260      F  1993-08-12               Uruguay               Bachelor
# 545   26310      F  1974-11-30              Guernsey               Bachelor
# 546   35330      N  1990-12-18               Andorra                 Master
# 547   49000      N  1965-09-26               Senegal  Less than high school
# 548   48470      M  1986-08-11               Romania  Less than high school
# 549   38480      M  1989-10-15               Croatia  Less than high school
# 550   28280      F  1983-01-24               Reunion                 Master
# 551   39420      M  1995-12-25               Senegal  Less than high school
# 552   26410      M  1967-09-01        United Kingdom  Less than high school
# 553   33720      F  1983-11-23               Liberia               Bachelor
# 554   23890      M  1965-08-11               Belgium            High school
# 555   31450      M  1974-07-28             Macedonia
# 556   24690      F  1969-03-21               Moldova            High school
# 557   30050      M  1969-10-18               Belgium                 Master
# 558   40940      F  1981-05-17             Greenland            High school
# 559   44460      M  1973-11-17              Thailand            High school
# 560   30720      F  1967-05-11                Cyprus                 Master
# 561   36140      M  1967-06-04             Gibraltar               Bachelor
# 562   23910      M  1967-05-10            Mozambique                 Master
# 563   36220      F  1975-05-08               Hungary               Bachelor
# 564   11600      M  2000-03-17                Mexico  Less than high school
# 565   49840      F  1984-10-26                France  Less than high school
# 566   26620      N  1999-04-03               Uruguay
# 567   37350      F  1989-04-04            Madagascar            High school
# 568   49190      F  1977-07-06                Jordan
# 569   20100      F  1969-08-23               Hungary               Bachelor
# 570   24340      F  2001-02-04               Moldova                 Master
# 571   49980      M  1989-03-21          South Africa               Bachelor
# 572   32580      M  1972-09-19            Madagascar               Bachelor
# 573   34380      M  1968-06-08          South Africa
#
#                 HOBBY
# 0           Laser tag
# 1       Ultra running
# 2             Pottery
# 3             Pottery
# 4            Hamsters
# 5               Other
# 6             Running
# 7        Cheerleading
# 8        Cheerleading
# 9          Beekeeping
# 10              Other
# 11            Macrame
# 12           Kayaking
# 13
# 14        Meteorology
# 15      Ultra running
# 16          Paintball
# 17         Embroidery
# 18           Painting
# 19          Laser tag
# 20              Other
# 21            Puzzles
# 22              Other
# 23            Hunting
# 24              Other
# 25            Hunting
# 26   Horseback riding
# 27            Puzzles
# 28         Embroidery
# 29             Flying
# ..                ...
# 544           Macrame
# 545            Flying
# 546         Paintball
# 547           Origami
# 548           Puzzles
# 549          Hamsters
# 550           Origami
# 551           Origami
# 552             Other
# 553        Embroidery
# 554     Ultra running
# 555          Painting
# 556        Embroidery
# 557           Hunting
# 558        Beekeeping
# 559        Beekeeping
# 560         Saxophone
# 561      Cheerleading
# 562         Laser tag
# 563           Pottery
# 564           Puzzles
# 565          Kayaking
# 566          Hamsters
# 567             Other
# 568         Saxophone
# 569         Laser tag
# 570
# 571         Saxophone
# 572          Kayaking
# 573         Paintball
#
# [574 rows x 6 columns]

# %%
#check dtypes 
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574 entries, 0 to 573
# Data columns (total 6 columns):
# USERID       574 non-null int64
# GENDER       574 non-null object
# DOB          574 non-null object
# COUNTRY      574 non-null object
# EDUCATION    574 non-null object
# HOBBY        574 non-null object
# dtypes: int64(1), object(5)
# memory usage: 27.0+ KB

# %% [markdown]
# #### Data-type contraints: cleaning, verifying and reporting

# %%
#change "DOB" field to date dtype

customers['DOB']= pd.to_datetime(customers['DOB'])

# %%
#check dtype again
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574 entries, 0 to 573
# Data columns (total 6 columns):
# USERID       574 non-null int64
# GENDER       574 non-null object
# DOB          574 non-null datetime64[ns]
# COUNTRY      574 non-null object
# EDUCATION    574 non-null object
# HOBBY        574 non-null object
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 27.0+ KB

# %% [markdown]
# ##### Reporting: As seen above, the currently stored customers data type meets the data-type contraints requirments.

# %%
# save a copy of the currently stored data in .csv file. 
customers_prep = pd.DataFrame(customers)
customers_prep.to_csv('customers_prep.csv')
customers_prep.to_csv(r'C:\Users\YUJI6004\customers_prep.csv', index=False)

# %% [markdown]
# ### B.2.3  Transaction Data

# %%
#read in transaction data 
transactions = pd.read_csv('TransactionsData.txt', sep='|', low_memory=False)
transactions
# Out:
#         USERID WEBBROWSER   PPC_ADD    ITEM PURCHASE QTY DISCOUNT  \
# 0        15410     CHROME     KEVIN  309261      YES   4       28
# 1        33510   EXPLORER     SENDI  484592      YES   4       30
# 2        26390  MOBILEAPP     KEVIN  191104      YES   2        4
# 3        48580  MOBILEAPP     SENDI  124180      YES   3       29
# 4        14600  MOBILEAPP     KEVIN  223591      YES            7
# 5        43930  MOBILEAPP  ISABELLA  147957      YES   2        4
# 6        18630     SAFARI  ISABELLA  467237      YES   2       11
# 7        44480   EXPLORER     SENDI  213633       NO   2       30
# 8        41980     CHROME        NO  211943       NO   2       17
# 9        13270     CHROME        NO  417382      YES   2       21
# 10       12170     SAFARI     KEVIN  496435      YES   2        7
# 11       18970  MOBILEAPP            473750      YES   2       14
# 12       43800     SAFARI        NO  224072      YES   2       30
# 13       42570   EXPLORER     KEVIN  233718      YES   2       14
# 14       10980  MOBILEAPP  ISABELLA  459437      YES   4       23
# 15       47230  MOBILEAPP     KEVIN  247537      YES   2       17
# 16       16820     CHROME    BIANCA  370283      YES   4        7
# 17       39960     CHROME     KEVIN  355944            2       17
# 18       29590     CHROME    BIANCA  278217      YES   3       28
# 19       21430     CHROME  ISABELLA  374287      YES   2       10
# 20       18630  MOBILEAPP        NO  413157      YES   4        8
# 21       38080     CHROME     KEVIN  430226      YES   2       11
# 22       14720     SAFARI        NO  290775      YES   2       24
# 23       12900   EXPLORER        NO  320662            2       15
# 24       36950   EXPLORER     KEVIN  433242      YES   3        4
# 25       32580               BIANCA  486100      YES   2       24
# 26       36770  MOBILEAPP        NO  358635            3       11
# 27       35050     CHROME     SENDI  108749      YES   2        8
# 28       33470   EXPLORER    BIANCA  176687      YES   2       29
# 29       19580     CHROME     KEVIN  296196      YES   3        2
# ...        ...        ...       ...     ...      ...  ..      ...
# 2188770  46390  MOBILEAPP            349730      YES   3       24
# 2188771  35460   EXPLORER    BIANCA  282832       NO   2        8
# 2188772  25680     SAFARI  ISABELLA  247797       NO   3        6
# 2188773  11410             ISABELLA  430707       NO   3       22
# 2188774  43460   EXPLORER     KEVIN  369607      YES   4       28
# 2188775  21350     CHROME  ISABELLA  448712       NO   3       20
# 2188776  49310     SAFARI    BIANCA  328098      YES   2       19
# 2188777  27620  MOBILEAPP        NO  213880            4       23
# 2188778  16170  MOBILEAPP    BIANCA  493055      YES   2        8
# 2188779  16720     CHROME     KEVIN  183642      YES   2        7
# 2188780  35330     SAFARI    BIANCA  341696      YES   3       21
# 2188781  19270     SAFARI        NO  456252      YES   4       18
# 2188782  25360   EXPLORER     KEVIN  451312      YES   2       29
# 2188783  39930  MOBILEAPP     SENDI  254063            3       23
# 2188784  36740  MOBILEAPP  ISABELLA  247056      YES   2       16
# 2188785  24340     CHROME    BIANCA  310769      YES   3        8
# 2188786  36770     CHROME        NO  209967      YES   2       26
# 2188787  43950     CHROME    BIANCA  378460      YES   3        6
# 2188788  33940  MOBILEAPP     SENDI  313850      YES            6
# 2188789  14270     CHROME        NO  404967      YES   2       10
# 2188790  24340  MOBILEAPP     SENDI  461738       NO   2        1
# 2188791  37500     CHROME     KEVIN  351901      YES   3       13
# 2188792  24250                   NO  218937      YES   2       17
# 2188793  29060  MOBILEAPP  ISABELLA  460633      YES   3       13
# 2188794  39790     CHROME     KENZA  138272      YES   3       16
# 2188795  14500   EXPLORER     KENZA  387248      YES   3        5
# 2188796  12070  MOBILEAPP     KEVIN  437259      YES   2       13
# 2188797  42150     CHROME     KEVIN  204442      YES   2        4
# 2188798  46950     CHROME     KEVIN  438793      YES   2       25
# 2188799  36420     CHROME     KEVIN  271184      YES   2        5
#
#                  PAYMENT WAREHOUSE SHIPDAYS DELIVERYDATE REVIEW RATING  \
# 0              APPLE PAY         D        6    2018-5-25     NO      1
# 1                                D        5     2018-5-1     NO      4
# 2                                B        7     2018-7-7    YES
# 3                   AMEX         E        5    2018-2-13     NO      3
# 4              APPLE PAY         B        6    2018-1-10     NO
# 5                 PAYPAL                  1    2018-7-20    YES      4
# 6        VISA/MASTERCARD         B        5   2018-11-21    YES      2
# 7                 PAYPAL         E              2018-2-6    YES      4
# 8        VISA/MASTERCARD         D        3    2018-3-26    YES      4
# 9                 PAYPAL                 10     2018-2-6    YES      4
# 10             APPLE PAY         B        5    2018-10-3    YES      5
# 11             APPLE PAY         E        8   2018-11-21    YES      2
# 12       VISA/MASTERCARD         C        5    2018-10-7     NO      2
# 13                PAYPAL         B        8    2018-5-14     NO      1
# 14             APPLE PAY                  5   2018-11-21    YES      5
# 15             APPLE PAY         D        7    2018-5-20     NO      4
# 16             APPLE PAY         C             2018-3-24     NO      2
# 17                PAYPAL         C        8    2018-4-24     NO      2
# 18                  AMEX         A             2018-2-13    YES      4
# 19             APPLE PAY         E       10    2018-10-3     NO
# 20             APPLE PAY         B        1    2018-3-24    YES      2
# 21                               A        5    2018-2-13    YES      5
# 22             APPLE PAY         A             2018-5-14     NO      5
# 23                               B       10    2018-5-25     NO      4
# 24       VISA/MASTERCARD         B        8     2018-2-6    YES      4
# 25             APPLE PAY         E        1   2018-11-21    YES
# 26                PAYPAL                 10    2018-7-20    YES      2
# 27             APPLE PAY         B             2018-10-3     NO      5
# 28       VISA/MASTERCARD         B        1   2018-11-21             4
# 29             APPLE PAY         D        5    2018-12-8    YES      1
# ...                  ...       ...      ...          ...    ...    ...
# 2188770                          D        8    2018-5-17             4
# 2188771  VISA/MASTERCARD         B        8   2018-11-21     NO      1
# 2188772             AMEX         C       10    2018-2-13    YES      1
# 2188773  VISA/MASTERCARD         C        5    2018-1-13     NO      3
# 2188774                          E        3     2018-5-1     NO      3
# 2188775           PAYPAL         E       10    2018-3-24             2
# 2188776  VISA/MASTERCARD                  4    2018-7-20    YES      1
# 2188777  VISA/MASTERCARD         B        1    2018-5-20     NO      2
# 2188778  VISA/MASTERCARD         E        6   2018-11-21    YES      5
# 2188779                          A        4     2018-7-7     NO      2
# 2188780                          D        3    2018-4-24     NO      2
# 2188781                          E        8    2018-3-26     NO      5
# 2188782  VISA/MASTERCARD         E        7    2018-3-28     NO      1
# 2188783           PAYPAL         A        1   2018-10-19    YES
# 2188784             AMEX         B        4    2018-5-14    YES      1
# 2188785        APPLE PAY         B        4   2018-11-21     NO      1
# 2188786        APPLE PAY         D        8    2018-3-26    YES      4
# 2188787             AMEX         C        3    2018-4-24    YES      4
# 2188788           PAYPAL         C        2   2018-10-21     NO      4
# 2188789        APPLE PAY         A        1    2018-10-7     NO      4
# 2188790  VISA/MASTERCARD                  1    2018-12-8    YES
# 2188791           PAYPAL         E        1   2018-12-19    YES
# 2188792             AMEX         D        7     2018-5-1    YES      2
# 2188793                          B        5    2018-7-20             4
# 2188794                          D        1   2018-10-21             4
# 2188795           PAYPAL         D       10    2018-1-10     NO      5
# 2188796                          E        7    2018-3-28    YES
# 2188797             AMEX         D        5    2018-5-17
# 2188798        APPLE PAY         B                          YES      1
# 2188799  VISA/MASTERCARD         B        4     2018-7-3     NO
#
#         TRACKNO TIMESTAMP
# 0        348721  21:54:45
# 1        373987   5:44:25
# 2        421013   6:58:15
# 3        406643  12:50:23
# 4        365623   5:23:37
# 5        473430    2:47:2
# 6        310743   2:31:39
# 7        378318   7:56:56
# 8        387350   0:31:21
# 9        499544   0:31:21
# 10       416798  12:18:21
# 11       488276  12:48:46
# 12       428015   19:2:37
# 13       435909   5:44:25
# 14       312119   1:26:31
# 15       484185   23:7:53
# 16       361578   1:26:31
# 17       403799  15:18:22
# 18       373051   1:18:40
# 19       476053   2:31:39
# 20       328791    0:3:15
# 21       401595  12:48:46
# 22       455664  11:56:58
# 23       491333   11:9:59
# 24       469138   2:31:39
# 25       392996  12:50:23
# 26       348906   11:9:59
# 27       490627   12:16:2
# 28       344362   1:31:40
# 29       356942   11:9:59
# ...         ...       ...
# 2188770  498123  12:18:21
# 2188771  313661   0:44:26
# 2188772  428941   0:44:26
# 2188773  479984  23:16:25
# 2188774  446942   20:16:1
# 2188775  482444  12:18:21
# 2188776  413241    2:47:2
# 2188777  410084   2:31:39
# 2188778  488131   0:28:54
# 2188779  323321    5:55:3
# 2188780  446205  12:25:54
# 2188781  448913  23:16:25
# 2188782  375473   2:30:52
# 2188783  496026  11:23:13
# 2188784  317454   12:9:28
# 2188785  444735   9:54:58
# 2188786  465924   15:20:4
# 2188787  424134  12:25:54
# 2188788  358216   13:24:6
# 2188789  450073   6:58:15
# 2188790  330105  19:34:14
# 2188791  460835   6:58:15
# 2188792  347017   19:2:37
# 2188793  332824    2:47:2
# 2188794  344338   2:31:39
# 2188795  493114    10:0:5
# 2188796  394130  19:34:14
# 2188797  401492   5:23:37
# 2188798  313126   0:28:54
# 2188799  482947  12:18:21
#
# [2188800 rows x 15 columns]

# %% [markdown]
# #### Data-type contraints: cleaning, verifying and reporting

# %%
# check the raw data type and compare with data dictionary 
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2188800 entries, 0 to 2188799
# Data columns (total 15 columns):
# USERID          object
# WEBBROWSER      object
# PPC_ADD         object
# ITEM            int64
# PURCHASE        object
# QTY             object
# DISCOUNT        object
# PAYMENT         object
# WAREHOUSE       object
# SHIPDAYS        object
# DELIVERYDATE    object
# REVIEW          object
# RATING          object
# TRACKNO         object
# TIMESTAMP       object
# dtypes: int64(1), object(14)
# memory usage: 250.5+ MB

# %% [markdown]
# #### Correct the following datatypes in transactions DB:
# Rating(int64),TIMESTAMP(Time), UserID (int64 ), QTY(int64), Discount (int64),  SHIPDAYS(int64), DELIVERYDATE (Date),  TRACKNO(int64)

# %% [markdown]
# #### 1) Change "RATING" from object to int64

# %%
#Check unique values in RATING 
transactions.RATING.unique()
# Out:
# array(['1', '4', ' ', '3', '2', '5'], dtype=object)

# %%
# replace ' ' with 0 in RATING field 
transactions['RATING'].replace(to_replace = ' ',value ="0", inplace=True)

# %%
# Re-check unique values in RATING after replacement 
transactions['RATING'].unique()
# Out:
# array(['1', '4', '0', '3', '2', '5'], dtype=object)

# %%
# change data type 
transactions['RATING'] = transactions['RATING'].astype('int64')

# %%
# check datatype 
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2188800 entries, 0 to 2188799
# Data columns (total 15 columns):
# USERID          object
# WEBBROWSER      object
# PPC_ADD         object
# ITEM            int64
# PURCHASE        object
# QTY             object
# DISCOUNT        object
# PAYMENT         object
# WAREHOUSE       object
# SHIPDAYS        object
# DELIVERYDATE    object
# REVIEW          object
# RATING          int64
# TRACKNO         object
# TIMESTAMP       object
# dtypes: int64(2), object(13)
# memory usage: 250.5+ MB

# %% [markdown]
# #### 2) Change "TIMESTAMP" from object to timestamp

# %%
# check unique values in TIMESTAMP 
transactions['TIMESTAMP'].unique()
# Out:
# array(['21:54:45', '5:44:25', '6:58:15', '12:50:23', '5:23:37', '2:47:2',
#        '2:31:39', '7:56:56', '0:31:21', '12:18:21', '12:48:46', '19:2:37',
#        '1:26:31', '23:7:53', '15:18:22', '1:18:40', '0:3:15', '11:56:58',
#        '11:9:59', '12:16:2', '1:31:40', '20:11:54', '7:2:59', '12:9:28',
#        '12:7:37', '10:30:9', '0:28:54', '9:2:29', '11:23:13', '7:5:34',
#        '12:3:51', '13:9:53', '23:41:5', '20:18:53', '13:24:6', '13:57:21',
#        '12:25:54', '2:30:52', '1:45:36', '20:16:1', '9:54:58', '5:50:52',
#        ' ', '9:42:18', '9:9:58', '0:44:26', '21:9:24', '9:42:39',
#        '1:47:18', '12:25:23', '23:16:25', '5:56:53', '11:50:25',
#        '19:34:14', '10:0:5', '6:16:2', '1:13:51', '5:55:3', '2:8:26',
#        '15:20:4'], dtype=object)

# %%
#replace unknown timestamp (' ') with "00:00:00"
transactions['TIMESTAMP'].replace(to_replace = ' ',value ="00:00:00", inplace=True)

# %%
# re-check unique values in TIMESTAMP
transactions['TIMESTAMP'].unique()
# Out:
# array(['21:54:45', '5:44:25', '6:58:15', '12:50:23', '5:23:37', '2:47:2',
#        '2:31:39', '7:56:56', '0:31:21', '12:18:21', '12:48:46', '19:2:37',
#        '1:26:31', '23:7:53', '15:18:22', '1:18:40', '0:3:15', '11:56:58',
#        '11:9:59', '12:16:2', '1:31:40', '20:11:54', '7:2:59', '12:9:28',
#        '12:7:37', '10:30:9', '0:28:54', '9:2:29', '11:23:13', '7:5:34',
#        '12:3:51', '13:9:53', '23:41:5', '20:18:53', '13:24:6', '13:57:21',
#        '12:25:54', '2:30:52', '1:45:36', '20:16:1', '9:54:58', '5:50:52',
#        '00:00:00', '9:42:18', '9:9:58', '0:44:26', '21:9:24', '9:42:39',
#        '1:47:18', '12:25:23', '23:16:25', '5:56:53', '11:50:25',
#        '19:34:14', '10:0:5', '6:16:2', '1:13:51', '5:55:3', '2:8:26',
#        '15:20:4'], dtype=object)

# %%
transactions['TIMESTAMP'] = pd.to_timedelta(transactions['TIMESTAMP'])

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2188800 entries, 0 to 2188799
# Data columns (total 15 columns):
# USERID          object
# WEBBROWSER      object
# PPC_ADD         object
# ITEM            int64
# PURCHASE        object
# QTY             object
# DISCOUNT        object
# PAYMENT         object
# WAREHOUSE       object
# SHIPDAYS        object
# DELIVERYDATE    object
# REVIEW          object
# RATING          int64
# TRACKNO         object
# TIMESTAMP       timedelta64[ns]
# dtypes: int64(2), object(12), timedelta64[ns](1)
# memory usage: 250.5+ MB

# %%
transactions.TIMESTAMP.unique()
# Out:
# array([78885000000000, 20665000000000, 25095000000000, 46223000000000,
#        19417000000000, 10022000000000,  9099000000000, 28616000000000,
#         1881000000000, 44301000000000, 46126000000000, 68557000000000,
#         5191000000000, 83273000000000, 55102000000000,  4720000000000,
#          195000000000, 43018000000000, 40199000000000, 44162000000000,
#         5500000000000, 72714000000000, 25379000000000, 43768000000000,
#        43657000000000, 37809000000000,  1734000000000, 32549000000000,
#        40993000000000, 25534000000000, 43431000000000, 47393000000000,
#        85265000000000, 73133000000000, 48246000000000, 50241000000000,
#        44754000000000,  9052000000000,  6336000000000, 72961000000000,
#        35698000000000, 21052000000000,              0, 34938000000000,
#        32998000000000,  2666000000000, 76164000000000, 34959000000000,
#         6438000000000, 44723000000000, 83785000000000, 21413000000000,
#        42625000000000, 70454000000000, 36005000000000, 22562000000000,
#         4431000000000, 21303000000000,  7706000000000, 55204000000000],
#       dtype='timedelta64[ns]')

# %% [markdown]
# #### 3) Change "USERID" from object to int64

# %%
transactions.USERID.unique()
# Out:
# array(['15410', '33510', '26390', '48580', '14600', '43930', '18630',
#        '44480', '41980', '13270', '12170', '18970', '43800', '42570',
#        '10980', '47230', '16820', '39960', '29590', '21430', '38080',
#        '14720', '12900', '36950', '32580', '36770', '35050', '33470',
#        '19580', '13940', '13560', '45260', '32950', '14480', '45590',
#        '16040', '42920', '28250', '48760', '14940', '36740', '41930',
#        '26970', '14440', '11080', '31950', '26930', '14070', '29310',
#        '37500', '42170', '43600', ' ', '14790', '30360', '42980', '40380',
#        '26130', '27320', '25630', '43290', '44620', '12130', '21830',
#        '23820', '12420', '38860', '31750', '40060', '28900', '27550',
#        '16610', '32340', '29070', '20760', '18490', '36980', '21960',
#        '39400', '24160', '11630', '31340', '16360', '33720', '37700',
#        '23520', '15770', '40810', '43920', '28650', '35110', '40340',
#        '19420', '34140', '31310', '39360', '36180', '38130', '23450',
#        '43540', '47850', '26860', '43420', '42150', '26100', '12570',
#        '11810', '37810', '18500', '21970', '28890', '25490', '47460',
#        '13830', '48030', '12440', '38610', '15240', '17700', '19190',
#        '13080', '19990', '42490', '47200', '18450', '38880', '20030',
#        '10210', '35430', '26950', '12990', '23150', '17670', '46460',
#        '37870', '10090', '23050', '12550', '44020', '33220', '15600',
#        '48520', '18480', '41550', '20880', '22200', '25330', '48390',
#        '46950', '28260', '43080', '19310', '33440', '35450', '31590',
#        '42460', '16720', '24340', '30520', '49980', '35480', '14970',
#        '10360', '48630', '49550', '18940', '12150', '10060', '36220',
#        '38810', '47210', '37100', '34600', '29860', '21310', '43240',
#        '44970', '24310', '23840', '24190', '29110', '45860', '24930',
#        '29710', '10120', '17080', '23530', '43990', '42220', '11910',
#        '23890', '30560', '26120', '21850', '49430', '27770', '20100',
#        '18040', '10330', '46500', '17690', '15970', '45370', '11970',
#        '17820', '24690', '36510', '32670', '12670', '46000', '49190',
#        '42800', '32020', '18130', '46590', '34490', '21500', '17570',
#        '16560', '48860', '11380', '29060', '49000', '39150', '39320',
#        '46310', '42790', '19140', '17410', '17970', '14110', '21350',
#        '31010', '43460', '21320', '25460', '36350', '23910', '37900',
#        '15500', '37890', '17190', '41240', '48980', '26700', '37090',
#        '13060', '12070', '11370', '24670', '49080', '13170', '49310',
#        '27660', '15700', '35790', '22890', '49100', '48310', '14270',
#        '49260', '20020', '36780', '36940', '44350', '49330', '48220',
#        '12650', '26940', '27530', '11410', '28930', '42700', '46850',
#        '15170', '45940', '22360', '20690', '21160', '40940', '44840',
#        '13570', '20200', '32350', '13240', '40360', '34560', '13660',
#        '49420', '26050', '21780', '22580', '24920', '29870', '34230',
#        '22830', '27920', '22170', '24910', '18720', '30300', '40980',
#        '41810', '16050', '26620', '32870', '27760', '39790', '29690',
#        '42810', '38530', '10880', '44920', '13860', '31510', '34160',
#        '30610', '37350', '27110', '46220', '30670', '11120', '12110',
#        '42430', '44690', '39130', '25160', '10680', '45950', '23290',
#        '48550', '42630', '43900', '25670', '33360', '16370', '26370',
#        '42370', '34700', '39420', '26750', '32810', '27870', '22850',
#        '23920', '17110', '36790', '36610', '16790', '21380', '27260',
#        '25170', '21800', '30730', '37470', '13070', '37720', '48470',
#        '43950', '48040', '20010', '22600', '34610', '38020', '35040',
#        '45040', '46890', '30350', '26710', '37570', '49710', '17620',
#        '17500', '26610', '39300', '14960', '26410', '28800', '23180',
#        '28370', '30500', '25770', '31700', '19270', '22480', '45240',
#        '40240', '35460', '36140', '45390', '38290', '42840', '44880',
#        '26280', '25720', '29020', '43630', '33490', '40640', '23260',
#        '13850', '26490', '19550', '25080', '46490', '31450', '25700',
#        '38190', '25510', '24250', '44040', '26190', '27620', '37460',
#        '30050', '20190', '43510', '23300', '44340', '34550', '40530',
#        '31670', '16460', '32960', '40220', '45990', '34760', '25990',
#        '45060', '44460', '14500', '39970', '10940', '43640', '22800',
#        '28090', '38480', '14730', '25850', '27010', '33280', '26300',
#        '48100', '30620', '14160', '20160', '10990', '39920', '12080',
#        '24010', '17880', '37480', '34400', '11600', '24200', '20530',
#        '24700', '41130', '40450', '37940', '28280', '35240', '18080',
#        '28580', '19600', '30720', '37610', '33690', '27480', '34070',
#        '41500', '13200', '12060', '29910', '16850', '15370', '29220',
#        '11400', '19060', '31650', '21200', '36600', '46910', '20590',
#        '46990', '21090', '45580', '40590', '27640', '31880', '44170',
#        '17040', '34590', '49400', '22130', '49790', '27080', '17240',
#        '16170', '16970', '24420', '46700', '16390', '46530', '39930',
#        '16080', '16600', '10180', '47620', '46390', '42340', '26310',
#        '20860', '15740', '46380', '37120', '15010', '42550', '10970',
#        '18540', '41590', '29450', '26290', '49840', '36210', '21300',
#        '45820', '35330', '38970', '46790', '10600', '30230', '14010',
#        '35580', '38140', '32650', '15150', '22410', '18430', '29980',
#        '42330', '40290', '35500', '25360', '25680', '28620', '43690',
#        '27890', '36420', '28600', '34390', '38990', '39650', '32730',
#        '16160', '44810', '47590', '10140', '34310', '27840', '34380',
#        '33940', '48850', '48950', '45220', '15720', '27120', '39060',
#        '48690', '11230', '36890', '19970', '33760', '14880', '22180'],
#       dtype=object)

# %%
transactions.USERID.max()
# Out:
# '49980'

# %%
#replace unknown USERID (' ') with "99999"
transactions['USERID'].replace(to_replace = ' ',value ='50000', inplace = True)

# %%
transactions.USERID = transactions.USERID.astype('int64')

# %%
transactions.USERID.dtype
# Out:
# dtype('int64')

# %% [markdown]
# #### 4) Change "QTY" from object to int64

# %%
transactions.QTY = transactions.USERID.astype('int64')

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2188800 entries, 0 to 2188799
# Data columns (total 15 columns):
# USERID          int64
# WEBBROWSER      object
# PPC_ADD         object
# ITEM            int64
# PURCHASE        object
# QTY             int64
# DISCOUNT        object
# PAYMENT         object
# WAREHOUSE       object
# SHIPDAYS        object
# DELIVERYDATE    object
# REVIEW          object
# RATING          int64
# TRACKNO         object
# TIMESTAMP       timedelta64[ns]
# dtypes: int64(4), object(10), timedelta64[ns](1)
# memory usage: 250.5+ MB

# %% [markdown]
# #### 5) Change "DISCOUNT" from object to int64

# %%
transactions.DISCOUNT.unique()
# Out:
# array(['28', '30', '4', '29', '7', '11', '17', '21', '14', '23', '10',
#        '8', '24', '15', '2', '5', '20', '19', '26', '1', '25', '18', '13',
#        '6', '16', '27', '22', ' ', '3', '9'], dtype=object)

# %%
transactions.DISCOUNT.replace(to_replace = ' ',value ='00', inplace = True)

# %%
transactions.DISCOUNT.unique()
# Out:
# array(['28', '30', '4', '29', '7', '11', '17', '21', '14', '23', '10',
#        '8', '24', '15', '2', '5', '20', '19', '26', '1', '25', '18', '13',
#        '6', '16', '27', '22', '00', '3', '9'], dtype=object)

# %%
transactions.DISCOUNT = transactions.DISCOUNT.astype('int64')

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2188800 entries, 0 to 2188799
# Data columns (total 15 columns):
# USERID          int64
# WEBBROWSER      object
# PPC_ADD         object
# ITEM            int64
# PURCHASE        object
# QTY             int64
# DISCOUNT        int64
# PAYMENT         object
# WAREHOUSE       object
# SHIPDAYS        object
# DELIVERYDATE    object
# REVIEW          object
# RATING          int64
# TRACKNO         object
# TIMESTAMP       timedelta64[ns]
# dtypes: int64(5), object(9), timedelta64[ns](1)
# memory usage: 250.5+ MB

# %% [markdown]
# #### 6) Change "SHIPDAYS " from object to int64

# %%
transactions.SHIPDAYS.unique()
# Out:
# array(['6', '5', '7', '1', ' ', '3', '10', '8', '2', '4'], dtype=object)

# %%
transactions.SHIPDAYS.replace(to_replace = ' ',value ='00', inplace = True)

# %%
transactions.SHIPDAYS = transactions.SHIPDAYS.astype('int64')

# %%
transactions.SHIPDAYS.dtype
# Out:
# dtype('int64')

# %%
transactions.SHIPDAYS.unique()
# Out:
# array([ 6,  5,  7,  1,  0,  3, 10,  8,  2,  4], dtype=int64)

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2188800 entries, 0 to 2188799
# Data columns (total 15 columns):
# USERID          int64
# WEBBROWSER      object
# PPC_ADD         object
# ITEM            int64
# PURCHASE        object
# QTY             int64
# DISCOUNT        int64
# PAYMENT         object
# WAREHOUSE       object
# SHIPDAYS        int64
# DELIVERYDATE    object
# REVIEW          object
# RATING          int64
# TRACKNO         object
# TIMESTAMP       timedelta64[ns]
# dtypes: int64(6), object(8), timedelta64[ns](1)
# memory usage: 250.5+ MB

# %% [markdown]
# #### 7) Change "DELIVERYDATE " from object to date

# %%
transactions['DELIVERYDATE'].unique()
# Out:
# array(['2018-5-25', '2018-5-1', '2018-7-7', '2018-2-13', '2018-1-10',
#        '2018-7-20', '2018-11-21', '2018-2-6', '2018-3-26', '2018-10-3',
#        '2018-10-7', '2018-5-14', '2018-5-20', '2018-3-24', '2018-4-24',
#        '2018-12-8', '2018-1-27', '2018-10-21', '2018-10-19', '2018-3-13',
#        '2018-5-17', '2018-4-23', '2018-12-19', '2018-11-23', '2018-3-28',
#        '2018-7-3', '2018-1-13', ' '], dtype=object)

# %%
transactions.DELIVERYDATE.replace(to_replace = ' ',value ='2019-12-30', inplace = True)

# %%
transactions['DELIVERYDATE'].unique()
# Out:
# array(['2018-5-25', '2018-5-1', '2018-7-7', '2018-2-13', '2018-1-10',
#        '2018-7-20', '2018-11-21', '2018-2-6', '2018-3-26', '2018-10-3',
#        '2018-10-7', '2018-5-14', '2018-5-20', '2018-3-24', '2018-4-24',
#        '2018-12-8', '2018-1-27', '2018-10-21', '2018-10-19', '2018-3-13',
#        '2018-5-17', '2018-4-23', '2018-12-19', '2018-11-23', '2018-3-28',
#        '2018-7-3', '2018-1-13', '2019-12-30'], dtype=object)

# %%
transactions['DELIVERYDATE']= pd.to_datetime(transactions['DELIVERYDATE'])

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2188800 entries, 0 to 2188799
# Data columns (total 15 columns):
# USERID          int64
# WEBBROWSER      object
# PPC_ADD         object
# ITEM            int64
# PURCHASE        object
# QTY             int64
# DISCOUNT        int64
# PAYMENT         object
# WAREHOUSE       object
# SHIPDAYS        int64
# DELIVERYDATE    datetime64[ns]
# REVIEW          object
# RATING          int64
# TRACKNO         object
# TIMESTAMP       timedelta64[ns]
# dtypes: datetime64[ns](1), int64(6), object(7), timedelta64[ns](1)
# memory usage: 250.5+ MB

# %%
transactions.head()
# Out:
#    USERID WEBBROWSER PPC_ADD    ITEM PURCHASE    QTY  DISCOUNT    PAYMENT  \
# 0   15410     CHROME   KEVIN  309261      YES  15410        28  APPLE PAY
# 1   33510   EXPLORER   SENDI  484592      YES  33510        30
# 2   26390  MOBILEAPP   KEVIN  191104      YES  26390         4
# 3   48580  MOBILEAPP   SENDI  124180      YES  48580        29       AMEX
# 4   14600  MOBILEAPP   KEVIN  223591      YES  14600         7  APPLE PAY
#
#   WAREHOUSE  SHIPDAYS DELIVERYDATE REVIEW  RATING TRACKNO TIMESTAMP
# 0         D         6   2018-05-25     NO       1  348721  21:54:45
# 1         D         5   2018-05-01     NO       4  373987  05:44:25
# 2         B         7   2018-07-07    YES       0  421013  06:58:15
# 3         E         5   2018-02-13     NO       3  406643  12:50:23
# 4         B         6   2018-01-10     NO       0  365623  05:23:37

# %% [markdown]
# #### 8) Change "TRACKNO" from object to int64

# %%
transactions.TRACKNO.unique()
# Out:
# array(['348721', '373987', '421013', ..., '403626', '477380', '320491'],
#       dtype=object)

# %%
transactions.TRACKNO.max()
# Out:
# '4e+05'

# %%
transactions.TRACKNO.replace(to_replace = '3e+05',value ='300000', inplace = True) 
transactions.TRACKNO.replace(to_replace = '4e+05',value ='400000', inplace = True) 
transactions.TRACKNO.replace(to_replace = ' ',value ='500000', inplace = True)

# %%
transactions.TRACKNO = transactions.TRACKNO.astype('int64')

# %% [markdown]
# #### Validate date types and data display

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2188800 entries, 0 to 2188799
# Data columns (total 15 columns):
# USERID          int64
# WEBBROWSER      object
# PPC_ADD         object
# ITEM            int64
# PURCHASE        object
# QTY             int64
# DISCOUNT        int64
# PAYMENT         object
# WAREHOUSE       object
# SHIPDAYS        int64
# DELIVERYDATE    datetime64[ns]
# REVIEW          object
# RATING          int64
# TRACKNO         int64
# TIMESTAMP       timedelta64[ns]
# dtypes: datetime64[ns](1), int64(7), object(6), timedelta64[ns](1)
# memory usage: 250.5+ MB

# %%
transactions.head()
# Out:
#    USERID WEBBROWSER PPC_ADD    ITEM PURCHASE    QTY  DISCOUNT    PAYMENT  \
# 0   15410     CHROME   KEVIN  309261      YES  15410        28  APPLE PAY
# 1   33510   EXPLORER   SENDI  484592      YES  33510        30
# 2   26390  MOBILEAPP   KEVIN  191104      YES  26390         4
# 3   48580  MOBILEAPP   SENDI  124180      YES  48580        29       AMEX
# 4   14600  MOBILEAPP   KEVIN  223591      YES  14600         7  APPLE PAY
#
#   WAREHOUSE  SHIPDAYS DELIVERYDATE REVIEW  RATING  TRACKNO TIMESTAMP
# 0         D         6   2018-05-25     NO       1   348721  21:54:45
# 1         D         5   2018-05-01     NO       4   373987  05:44:25
# 2         B         7   2018-07-07    YES       0   421013  06:58:15
# 3         E         5   2018-02-13     NO       3   406643  12:50:23
# 4         B         6   2018-01-10     NO       0   365623  05:23:37

# %% [markdown]
# ##### Reporting: As seen above, the currently stored transactions data type meets the data-type contraints requirments.

# %%
# save a copy of the currently stored transaction database as .csv
transactions_prep = pd.DataFrame(transactions)
transactions_prep.to_csv('transactions_prep.csv')
transactions_prep.to_csv(r'C:\Users\YUJI6004\transactions_prep.csv', index=False)

# %% [markdown]
# ## B.3   Data Cleaning

# %% [markdown]
# ### B.3.1  Data Quality
# #### Items Data

# %% [markdown]
# #### 1) Check for duplicated rows

# %%
items_prep.duplicated(['ITEM', 'CATEGORY', 'COLOR', 'SUPLID', 'PURCHASEPRICE', 'SALEPRICE']).value_counts()
# Out:
# True     1904410
# False     284390
# dtype: int64

# %%
items_prep.duplicated(['ITEM', 'CATEGORY', 'COLOR', 'SUPLID', 'PURCHASEPRICE', 'SALEPRICE']).value_counts()*100/len(items_prep)
# Out:
# True     87.007036
# False    12.992964
# dtype: float64

# %% [markdown]
# #### Reporting: as seen above, almost 87% of data are duplicates across all fields. We need to remove duplicates.

# %%
# drop duplicates 
items_prep.drop_duplicates(inplace=True)

# %%
# verify if duplicates are dropped 
items_prep.duplicated(['ITEM', 'CATEGORY', 'COLOR', 'SUPLID', 'PURCHASEPRICE', 'SALEPRICE']).value_counts()
# Out:
# False    284390
# dtype: int64

# %% [markdown]
# #### 1) Check Range Constraints: ITEM, CATEGORY, COLOR

# %%
# Let's start with quantitative variables 
items_prep.describe()
# Out:
#                 ITEM  PURCHASEPRICE      SALEPRICE
# count  284390.000000  284390.000000  284390.000000
# mean   298372.001062    1001.057978    1343.938113
# std    115279.872551     577.360400     842.701588
# min    100013.000000       0.000000       0.000000
# 25%    199528.000000     494.090000     640.000000
# 50%    296885.000000    1007.460000    1280.000000
# 75%    397557.000000    1504.110000    1980.000000
# max    499997.000000    1999.700000    3600.000000

# %%
items_prep.ITEM.nunique()
# Out:
# 10944

# %% [markdown]
# ##### As seen above, item is within [100000, 500000] range.

# %%
# display disctinct value in COLOR
items_prep.COLOR.unique()
# Out:
# array(['PINK', 'GOLD', 'SILVER', 'RAINBOW', 'VIOLET'], dtype=object)

# %%
# display unique values in CATEGORY
items_prep.CATEGORY.unique()
# Out:
# array(['PAJAMAS', 'SOCKS', 'COAT', 'DRESS', 'SCARF', 'BELT', 'JACKET',
#        'PANTS', 'HAT', 'GLOVES', 'TIE', 'SKIRT', 'STOCKINGS', 'SHIRT',
#        'UNDERPANTS', 'JEANS', 'SUIT', 'SHOES'], dtype=object)

# %% [markdown]
# ##### As seen above, COLOR and CATEGORY are within the Length requirements.

# %% [markdown]
# #### 2) Check Unique Constraints, missing values and determine primary /composite keys

# %%
# count distinct values in ITEM field 
items_prep.ITEM.nunique()
# Out:
# 10944

# %% [markdown]
# #### Reporting: As seen above, ITEM field is not a primary key. In fact, ITEM field could be a foreign key to TransactionDB; COLOR and CATEGORY is distinct to each ITEM code.

# %%
# number of COLOR
items_prep.COLOR.value_counts().count()
# Out:
# 5

# %%
# number of categories 
items_prep.CATEGORY.value_counts().count()
# Out:
# 18

# %% [markdown]
# #### Determining primary key or composite key field(s)

# %%
# find number of distinct SUPLID
items_prep.SUPLID.nunique()
# Out:
# 25

# %% [markdown]
# #### check missing values

# %%
items_prep.notnull().sum()
# Out:
# ITEM             284390
# CATEGORY         284390
# COLOR            284390
# SUPLID           273450
# PURCHASEPRICE    284390
# SALEPRICE        284390
# dtype: int64

# %%
print('' in items_prep['SUPLID'])
# Out:
# False

# %%
print('null' in items_prep['SUPLID'])
# Out:
# False

# %%
# Check counts of missing values
items_prep.isnull().sum()*100/len(items_prep)
# Out:
# ITEM             0.00000
# CATEGORY         0.00000
# COLOR            0.00000
# SUPLID           3.84683
# PURCHASEPRICE    0.00000
# SALEPRICE        0.00000
# dtype: float64

# %% [markdown]
# #### Reporting: As seen above, there are 3.84% of missing data in SUPLID.

# %%
# count the number of missing values in PURCHASEPRICE
items_prep[items_prep.PURCHASEPRICE == 0.0].count()
# Out:
# ITEM             26
# CATEGORY         26
# COLOR            26
# SUPLID           25
# PURCHASEPRICE    26
# SALEPRICE        26
# dtype: int64

# %%
# count the % of missing values in PURCHASEPRICE
items_prep[items_prep.PURCHASEPRICE == 0.0].count()*100/len(items_prep)
# Out:
# ITEM             0.009142
# CATEGORY         0.009142
# COLOR            0.009142
# SUPLID           0.008791
# PURCHASEPRICE    0.009142
# SALEPRICE        0.009142
# dtype: float64

# %% [markdown]
# #### As seen above, there are 0.009 % of missing PURCHASEPRICE (n=200)

# %%
items_prep[items_prep.PURCHASEPRICE == 0.0].groupby(['SALEPRICE']).count()
# Out:
#            ITEM  CATEGORY  COLOR  SUPLID  PURCHASEPRICE
# SALEPRICE
# 0.0          26        26     26      25             26

# %% [markdown]
# #### As seen above, there are 0.009 % of missing SALEPRICE (n=200)

# %% [markdown]
# #### Reporting: 1)  ITEM is a foreign Key. Each item refers to distinct COLOR and CATEGORY. The same ITEM can have multiple SUPLID.  2) No missing values except those in SUPLID field.

# %% [markdown]
# ### Decompose ITEMDB

# %%
supls = pd.DataFrame(items_prep, columns = ['SUPLID', 'PURCHASEPRICE', 'ITEM' ])
supls.head()
# Out:
#     SUPLID  PURCHASEPRICE    ITEM
# 0  41560EE        1867.09  127521
# 1  16091ZZ        1862.08  151662
# 2  11370LL         914.81  453756
# 3  41560EE        1913.00  434386
# 4  48094JJ         851.43  422712

# %%
supls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 284390 entries, 0 to 2180594
# Data columns (total 3 columns):
# SUPLID           273450 non-null object
# PURCHASEPRICE    284390 non-null float64
# ITEM             284390 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 18.7+ MB

# %%
supls.SUPLID.unique()
# Out:
# array(['41560EE', '16091ZZ', '11370LL', '48094JJ', '41560MM', '11370TT',
#        '42596VV', '43136JJ', '42258KK', nan, '46396EE', '41560GG',
#        '18767CC', '46848VV', '42596PP', '16091DD', '46848AA', '48094CC',
#        '42258WW', '13205GG', '18767GG', '14656DD', '46396XX', '43136TT',
#        '14656UU', '13205VV'], dtype=object)

# %%
supls.isnull().sum()
# Out:
# SUPLID           10940
# PURCHASEPRICE        0
# ITEM                 0
# dtype: int64

# %%
supls.SUPLID.value_counts()
# Out:
# 48094JJ    10944
# 41560MM    10941
# 11370LL    10940
# 46848VV    10940
# 42258KK    10940
# 41560GG    10940
# 48094CC    10940
# 18767CC    10940
# 42258WW    10939
# 43136TT    10939
# 13205GG    10939
# 46396EE    10939
# 18767GG    10938
# 13205VV    10937
# 14656DD    10937
# 11370TT    10937
# 16091ZZ    10937
# 46848AA    10937
# 14656UU    10937
# 16091DD    10937
# 43136JJ    10936
# 42596VV    10935
# 41560EE    10935
# 46396XX    10933
# 42596PP    10933
# Name: SUPLID, dtype: int64

# %%
supls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 284390 entries, 0 to 2180594
# Data columns (total 3 columns):
# SUPLID           273450 non-null object
# PURCHASEPRICE    284390 non-null float64
# ITEM             284390 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 18.7+ MB

# %%
supls.SUPLID[supls.SUPLID==' '].count()
# Out:
# 0

# %%
#### Save a copy of items pre-processed data 
items_prep = pd.DataFrame(items)
items_prep.to_csv('items_prep.csv')
items_prep.to_csv(r'C:\Users\YUJI6004\items_prep.csv', index=False)
# load the saved copy and verify dtypes consistency 
items_prep = pd.read_csv('items_prep.csv', sep =',')
items_prep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2188800 entries, 0 to 2188799
# Data columns (total 6 columns):
# ITEM             int64
# CATEGORY         object
# COLOR            object
# SUPLID           object
# PURCHASEPRICE    float64
# SALEPRICE        float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 100.2+ MB

# %% [markdown]
# ### Customers dataset
#
# #### 1) Check range constraints of USERID and GENDER fields

# %%
#check statistics of quantitative variable 
customers.describe()
# Out:
#              USERID
# count    574.000000
# mean   29972.229965
# std    11550.527178
# min    10060.000000
# 25%    20047.500000
# 50%    29380.000000
# 75%    39952.500000
# max    49980.000000

# %%
# check data integrity of GENDER.
customers.GENDER.unique()
# Out:
# array(['F', 'M', 'N'], dtype=object)

# %% [markdown]
# #### Reporting: As seen above, USERID is within the required range [10000, 50000]. GENDER field meets with data constraints: [F, M,N]

# %% [markdown]
# #### 2) Check Primary/Foreign keys

# %%
#count the distinct number of USERID
customers.USERID.nunique()
# Out:
# 574

# %% [markdown]
# #### Reporting: As seen above, the count of total rows is the same as the number of unique values in USERIDs (=574). Thus, USERID is the primary key

# %% [markdown]
# #### 3) Check missing values

# %%
# check missing values in customers DB
customers.isna().any()
# Out:
# USERID       False
# GENDER       False
# DOB          False
# COUNTRY      False
# EDUCATION    False
# HOBBY        False
# dtype: bool

# %%
# count the number each GENDER 
customers.GENDER.value_counts()
# Out:
# F    304
# M    214
# N     56
# Name: GENDER, dtype: int64

# %% [markdown]
# #### As seen above, no missing values in the customer DB. However, it is worth mentiong that the GENDER field has 56 N USERIDs. Those are the USERs without gender info, perhaps their gender identity is not disclosed or considered as transgender, or representing other minor sexualities  etc.

# %%
# check unique values in COUNTRY
customers.COUNTRY.unique()
# Out:
# array(['Ethiopia', 'United Arab Emirates', 'Martinique', 'Germany',
#        'Madagascar', 'Guinea', 'Japan', 'Algeria', 'Puerto Rico',
#        'Antarctica', 'Senegal', 'France', 'Chile', 'Gibraltar', 'Reunion',
#        'Morocco', 'Mexico', 'Uruguay', 'Guernsey', 'Macedonia', 'Liberia',
#        'Jordan', 'Malta', 'Bahamas', 'Greenland', 'Cyprus', 'Mozambique',
#        'Sweden', 'Thailand', 'Uganda', 'South Africa', 'Andorra',
#        'Croatia', 'Barbados', 'Moldova', 'Faroe Islands', 'Romania',
#        'Italy', 'China', 'Venezuela', 'Hungary', 'United Kingdom',
#        'Rwanda', 'Belgium', 'South Korea'], dtype=object)

# %% [markdown]
# #### Reporting: as shown above, no missing values in COUNTRY

# %%
# check unique values in EDUCATION
customers.EDUCATION.unique()
# Out:
# array([' ', 'Bachelor', 'Master', 'High school', 'Less than high school'],
#       dtype=object)

# %%
customers.EDUCATION.value_counts(ascending=True)
# Out:
# Master                   106
# Null                     110
# Bachelor                 112
# Less than high school    117
# High school              129
# Name: EDUCATION, dtype: int64

# %%
customers.EDUCATION.value_counts(normalize=True)
# Out:
# High school              0.224739
# Less than high school    0.203833
# Bachelor                 0.195122
# Null                     0.191638
# Master                   0.184669
# Name: EDUCATION, dtype: float64

# %% [markdown]
# ##### As seen above, 19.16% of Education data is missing
#
# #### It is worth mentioning that ' ' is stored as a string, thus the isnull() function is evaluated as false.

# %%
# replace ' ' with Null in EDUCATION
customers.EDUCATION = customers.EDUCATION.replace(to_replace = ' ', value = 'Null')

# %%
# Verify the replacement 
customers.EDUCATION.unique()
# Out:
# array(['Null', 'Bachelor', 'Master', 'High school',
#        'Less than high school'], dtype=object)

# %%
# check unique values in HOBBY
customers.HOBBY.unique()
# Out:
# array(['Laser tag', 'Ultra running', 'Pottery', 'Hamsters', 'Other',
#        'Running', 'Cheerleading', 'Beekeeping', 'Macrame', 'Kayaking',
#        ' ', 'Meteorology', 'Paintball', 'Embroidery', 'Painting',
#        'Puzzles', 'Hunting', 'Horseback riding', 'Flying', 'Climbing',
#        'Geocaching', 'Saxophone', 'Sculpting', 'Origami', 'Gaming'],
#       dtype=object)

# %%
# check number of missing values in HOBBY
customers.HOBBY.value_counts(ascending=True)
# Out:
# Beekeeping          15
# Paintball           16
# Geocaching          17
# Cheerleading        17
#                     18
# Macrame             20
# Kayaking            20
# Puzzles             20
# Horseback riding    20
# Gaming              21
# Saxophone           23
# Climbing            23
# Meteorology         23
# Running             23
# Pottery             24
# Sculpting           24
# Hunting             25
# Painting            25
# Flying              25
# Ultra running       28
# Hamsters            28
# Other               28
# Laser tag           29
# Origami             30
# Embroidery          32
# Name: HOBBY, dtype: int64

# %%
# replace ' ' with Null in HOBBY
customers.HOBBY = customers.HOBBY.replace(to_replace = ' ', value = 'Null')

# %%
# Verify the replacement 
customers.EDUCATION.unique()
# Out:
# array(['Null', 'Bachelor', 'Master', 'High school',
#        'Less than high school'], dtype=object)

# %%
# check % of missing values in HOBBY
customers.HOBBY.value_counts(normalize=True)
# Out:
# Embroidery          0.055749
# Origami             0.052265
# Laser tag           0.050523
# Other               0.048780
# Hamsters            0.048780
# Ultra running       0.048780
# Flying              0.043554
# Painting            0.043554
# Hunting             0.043554
# Sculpting           0.041812
# Pottery             0.041812
# Running             0.040070
# Meteorology         0.040070
# Climbing            0.040070
# Saxophone           0.040070
# Gaming              0.036585
# Horseback riding    0.034843
# Puzzles             0.034843
# Kayaking            0.034843
# Macrame             0.034843
#                     0.031359
# Cheerleading        0.029617
# Geocaching          0.029617
# Paintball           0.027875
# Beekeeping          0.026132
# Name: HOBBY, dtype: float64

# %%
customers.sort_values('DOB',ascending = True)
# Out:
#      USERID GENDER        DOB               COUNTRY              EDUCATION  \
# 55    36420      N 1965-01-03               Moldova                   Null
# 541   42170      F 1965-01-10             Greenland                   Null
# 159   27840      F 1965-01-20             Gibraltar                 Master
# 425   37500      M 1965-02-10           South Korea                 Master
# 242   17190      M 1965-02-16                Guinea                 Master
# 290   42430      F 1965-04-10               Uruguay                   Null
# 402   49260      F 1965-05-13               Liberia            High school
# 246   15970      M 1965-05-24  United Arab Emirates            High school
# 366   48220      N 1965-08-07                Guinea                   Null
# 554   23890      M 1965-08-11               Belgium            High school
# 547   49000      N 1965-09-26               Senegal  Less than high school
# 371   12080      M 1965-10-15               Hungary  Less than high school
# 249   16160      M 1965-10-29                 Italy            High school
# 64    13560      F 1966-01-26                 Malta                 Master
# 34    21850      F 1966-02-20                 Chile               Bachelor
# 9     37480      M 1966-04-09            Antarctica                   Null
# 527   21970      F 1966-04-16               Moldova  Less than high school
# 52    35110      M 1966-05-05               Reunion               Bachelor
# 407   39360      M 1966-07-29              Thailand                 Master
# 350   49100      F 1966-08-06                Cyprus               Bachelor
# 165   21960      F 1966-09-12                 Italy  Less than high school
# 533   46000      M 1966-10-06         Faroe Islands  Less than high school
# 276   21830      M 1966-11-16              Barbados                   Null
# 141   26100      F 1967-02-28            Martinique                 Master
# 28    46530      F 1967-03-24                 Japan                   Null
# 418   47210      M 1967-04-08              Guernsey                   Null
# 409   25850      F 1967-04-27             Macedonia                   Null
# 521   42570      F 1967-05-08               Algeria            High school
# 562   23910      M 1967-05-10            Mozambique                 Master
# 560   30720      F 1967-05-11                Cyprus                 Master
# ..      ...    ...        ...                   ...                    ...
# 540   33940      M 2000-03-30            Martinique            High school
# 482   22830      F 2000-04-20               Romania  Less than high school
# 72    18430      F 2000-04-27                Mexico                   Null
# 113   29020      F 2000-05-15                Mexico               Bachelor
# 111   28600      F 2000-07-15             Gibraltar  Less than high school
# 261   36610      F 2000-07-16               Algeria                   Null
# 317   46700      M 2000-07-17               Andorra  Less than high school
# 435   45580      F 2000-07-20              Ethiopia            High school
# 537   13170      F 2000-09-10             Greenland  Less than high school
# 525   41590      M 2000-09-14               Croatia               Bachelor
# 222   32950      F 2000-09-18                Jordan               Bachelor
# 325   36950      F 2000-11-17             Greenland                 Master
# 211   35430      F 2000-11-21  United Arab Emirates               Bachelor
# 305   25460      M 2000-12-13          South Africa               Bachelor
# 8     27260      F 2000-12-28           Puerto Rico            High school
# 570   24340      F 2001-02-04               Moldova                 Master
# 486   40810      M 2001-02-16               Morocco  Less than high school
# 47    15770      F 2001-03-05                Guinea            High school
# 108   14730      F 2001-05-26               Reunion  Less than high school
# 83    33220      F 2001-06-24            Antarctica  Less than high school
# 98    12990      M 2001-07-20            Martinique                 Master
# 411   31650      F 2001-08-17             Macedonia                 Master
# 225   44840      N 2001-08-22                Sweden                 Master
# 506   27620      F 2001-09-12                Cyprus               Bachelor
# 410   32650      N 2001-09-29            Martinique  Less than high school
# 219   20020      M 2001-10-06          South Africa                   Null
# 491   36940      F 2001-10-26               Uruguay                   Null
# 252   29450      M 2001-11-13                Guinea                 Master
# 40    21350      M 2001-11-25               Germany                 Master
# 345   35580      M 2001-12-02               Croatia                   Null
#
#                 HOBBY
# 55         Geocaching
# 541     Ultra running
# 159        Geocaching
# 425     Ultra running
# 242          Kayaking
# 290          Painting
# 402           Hunting
# 246          Kayaking
# 366           Puzzles
# 554     Ultra running
# 547           Origami
# 371        Embroidery
# 249         Laser tag
# 64           Kayaking
# 34             Flying
# 9          Beekeeping
# 527           Macrame
# 52           Climbing
# 407       Meteorology
# 350            Gaming
# 165           Running
# 533        Beekeeping
# 276
# 141  Horseback riding
# 28         Embroidery
# 418           Pottery
# 409       Meteorology
# 521         Laser tag
# 562         Laser tag
# 560         Saxophone
# ..                ...
# 540           Puzzles
# 482           Puzzles
# 72
# 113           Pottery
# 111         Sculpting
# 261         Sculpting
# 317        Embroidery
# 435           Macrame
# 537       Meteorology
# 525           Origami
# 222          Climbing
# 325         Sculpting
# 211            Gaming
# 305       Meteorology
# 8        Cheerleading
# 570
# 486            Flying
# 47            Puzzles
# 108           Origami
# 83            Origami
# 98           Kayaking
# 411       Meteorology
# 225           Macrame
# 506         Saxophone
# 410         Saxophone
# 219           Macrame
# 491           Origami
# 252          Hamsters
# 40          Sculpting
# 345             Other
#
# [574 rows x 6 columns]

# %% [markdown]
# ##### Transactions dataset

# %%
transactions.head()
# Out:
#    USERID WEBBROWSER PPC_ADD    ITEM PURCHASE    QTY  DISCOUNT    PAYMENT  \
# 0   15410     CHROME   KEVIN  309261      YES  15410        28  APPLE PAY
# 1   33510   EXPLORER   SENDI  484592      YES  33510        30
# 2   26390  MOBILEAPP   KEVIN  191104      YES  26390         4
# 3   48580  MOBILEAPP   SENDI  124180      YES  48580        29       AMEX
# 4   14600  MOBILEAPP   KEVIN  223591      YES  14600         7  APPLE PAY
#
#   WAREHOUSE  SHIPDAYS DELIVERYDATE REVIEW  RATING  TRACKNO TIMESTAMP
# 0         D         6   2018-05-25     NO       1   348721  21:54:45
# 1         D         5   2018-05-01     NO       4   373987  05:44:25
# 2         B         7   2018-07-07    YES       0   421013  06:58:15
# 3         E         5   2018-02-13     NO       3   406643  12:50:23
# 4         B         6   2018-01-10     NO       0   365623  05:23:37

# %% [markdown]
# #### To start with, let's look at the quantitative variables

# %%
#check statistics of quantitative variable 
transactions.describe()
# Out:
#              USERID          ITEM           QTY      DISCOUNT      SHIPDAYS  \
# count  2.188800e+06  2.188800e+06  2.188800e+06  2.188800e+06  2.188800e+06
# mean   3.000972e+04  2.983991e+05  3.000972e+04  1.457914e+01  4.596594e+00
# std    1.156518e+04  1.152450e+05  1.156518e+04  8.974733e+00  3.039147e+00
# min    1.006000e+04  1.000130e+05  1.006000e+04  0.000000e+00  0.000000e+00
# 25%    2.003000e+04  1.995800e+05  2.003000e+04  7.000000e+00  2.000000e+00
# 50%    2.945000e+04  2.968850e+05  2.945000e+04  1.400000e+01  4.000000e+00
# 75%    3.997000e+04  3.975310e+05  3.997000e+04  2.200000e+01  7.000000e+00
# max    5.000000e+04  4.999970e+05  5.000000e+04  3.000000e+01  1.000000e+01
#
#              RATING       TRACKNO               TIMESTAMP
# count  2.188800e+06  2.188800e+06                 2188800
# mean   2.223496e+00  3.999524e+05  0 days 09:54:37.335662
# std    1.791621e+00  5.772411e+04  0 days 06:42:45.117814
# min    0.000000e+00  3.000000e+05         0 days 00:00:00
# 25%    0.000000e+00  3.499650e+05         0 days 05:23:37
# 50%    2.000000e+00  4.000260e+05         0 days 10:00:05
# 75%    4.000000e+00  4.499980e+05         0 days 12:50:23
# max    5.000000e+00  5.000000e+05         0 days 23:41:05

# %% [markdown]
# #### As seen above, the summary statistics of USERID and QTY is identical!! Thus, QTY is not a reliable field.

# %%
# count the number of distinct values in USERID
transactions.USERID.nunique()
# Out:
# 575

# %%
# count the number of distinct values in ITEM
transactions.ITEM.nunique()
# Out:
# 10944

# %%
# count the number of distinct values in QTY
transactions.QTY.nunique()
# Out:
# 575

# %%
transactions.sort_values('QTY', axis=0, ascending = True, na_position ='first')
# Out:
#          USERID WEBBROWSER   PPC_ADD    ITEM PURCHASE    QTY  DISCOUNT  \
# 2060360   10060  MOBILEAPP    BIANCA  227335      YES  10060        30
# 754547    10060   EXPLORER     KEVIN  371349      YES  10060        19
# 220058    10060  MOBILEAPP     KEVIN  485190      YES  10060        30
# 1518391   10060  MOBILEAPP        NO  116133      YES  10060         6
# 195986    10060  MOBILEAPP     SENDI  330373           10060        18
# 1786679   10060     CHROME        NO  388899      YES  10060        30
# 1057156   10060     CHROME     KEVIN  198228      YES  10060        23
# 1481543   10060  MOBILEAPP        NO  243442      YES  10060         6
# 1593234   10060     CHROME  ISABELLA  106474      YES  10060        23
# 1185166   10060     CHROME     KENZA  338732      YES  10060        19
# 1450184   10060  MOBILEAPP  ISABELLA  154431      YES  10060        18
# 1481616   10060     CHROME     KEVIN  199203      YES  10060        30
# 137304    10060     SAFARI  ISABELLA  283456      YES  10060        30
# 1853440   10060  MOBILEAPP        NO  269845      YES  10060        30
# 2071527   10060     CHROME        NO  125922       NO  10060        24
# 1258012   10060     CHROME     KEVIN  182433      YES  10060        28
# 1185018   10060     SAFARI     KENZA  116471      YES  10060        19
# 1969610   10060                   NO  193288      YES  10060        28
# 1899515   10060     SAFARI     KEVIN  119812      YES  10060        10
# 998473    10060     CHROME    BIANCA  392695      YES  10060        26
# 410976    10060     CHROME     SENDI  479899       NO  10060         4
# 3379      10060   EXPLORER  ISABELLA  348768      YES  10060        28
# 1517922   10060     CHROME  ISABELLA  325004           10060        20
# 1786043   10060  MOBILEAPP     KEVIN  313083      YES  10060         2
# 1660846   10060     CHROME        NO  357491      YES  10060        26
# 196235    10060     CHROME     KEVIN  211826      YES  10060        19
# 245695    10060     CHROME    BIANCA  304503      YES  10060        28
# 1969629   10060  MOBILEAPP     KEVIN  250046       NO  10060         3
# 1100406   10060     CHROME        NO  141379      YES  10060        18
# 1744645   10060     CHROME        NO  360559      YES  10060         6
# ...         ...        ...       ...     ...      ...    ...       ...
# 1823357   50000     SAFARI     KEVIN  464312      YES  50000        23
# 1703555   50000     CHROME            236201       NO  50000         4
# 1456890   50000                KEVIN  201829      YES  50000        28
# 1934808   50000  MOBILEAPP    BIANCA  375483      YES  50000        30
# 1976299   50000     CHROME     KENZA  404616      YES  50000         1
# 680652    50000     CHROME  ISABELLA  164519      YES  50000         5
# 2135844   50000  MOBILEAPP  ISABELLA  218248       NO  50000        23
# 1408128   50000     CHROME     KEVIN  365564       NO  50000        29
# 1479219   50000  MOBILEAPP     KEVIN  315137      YES  50000        29
# 2169268   50000     SAFARI    BIANCA  481277      YES  50000         1
# 2024191   50000  MOBILEAPP     KEVIN  296872           50000         1
# 710755    50000                   NO  267219      YES  50000         4
# 299991    50000   EXPLORER  ISABELLA  213412      YES  50000         1
# 2159159   50000  MOBILEAPP    BIANCA  412793      YES  50000        23
# 1985640   50000     CHROME    BIANCA  236500      YES  50000         6
# 1230698   50000     SAFARI     KEVIN  464806      YES  50000        16
# 56399     50000   EXPLORER     KENZA  142861      YES  50000        20
# 1746883   50000   EXPLORER  ISABELLA  229168      YES  50000         6
# 188056    50000               BIANCA  448712           50000        16
# 20009     50000     SAFARI  ISABELLA  359116      YES  50000         7
# 605790    50000     SAFARI  ISABELLA  180470      YES  50000         8
# 817361    50000  MOBILEAPP     SENDI  235850       NO  50000        23
# 164565    50000     SAFARI        NO  307090       NO  50000        10
# 1037603   50000     CHROME     SENDI  243455      YES  50000        29
# 680629    50000  MOBILEAPP     KEVIN  232522           50000         2
# 1013896   50000     CHROME    BIANCA  122321      YES  50000        23
# 1646382   50000     CHROME     SENDI  394060      YES  50000        29
# 1578874   50000  MOBILEAPP     KEVIN  488310      YES  50000         4
# 1695111   50000               BIANCA  329151      YES  50000        23
# 236131    50000   EXPLORER            382633       NO  50000         1
#
#                  PAYMENT WAREHOUSE  SHIPDAYS DELIVERYDATE REVIEW  RATING  \
# 2060360             AMEX         C         5   2018-03-28     NO       0
# 754547                           B         2   2018-10-19    YES       2
# 220058   VISA/MASTERCARD         D         2   2018-11-23     NO       5
# 1518391             AMEX         C         7   2018-03-26    YES       2
# 195986                                     5   2018-03-28    YES       1
# 1786679        APPLE PAY         C         1   2018-03-26    YES       1
# 1057156  VISA/MASTERCARD         B         6   2018-11-23     NO       5
# 1481543                          B         2   2018-05-25    YES       4
# 1593234        APPLE PAY         D         1   2018-11-23     NO       4
# 1185166             AMEX                   2   2018-07-07    YES       0
# 1450184             AMEX         B         5   2018-12-08    YES       2
# 1481616  VISA/MASTERCARD         D        10   2018-10-19     NO       4
# 137304              AMEX                   8   2018-03-13              0
# 1853440                                    8   2018-05-14    YES       4
# 2071527                                    2   2018-04-24    YES       0
# 1258012                          A         3   2018-01-13     NO       0
# 1185018        APPLE PAY         A         2   2018-07-03    YES       5
# 1969610           PAYPAL         B         0   2018-05-14     NO       2
# 1899515  VISA/MASTERCARD         C        10   2018-03-24     NO       1
# 998473              AMEX         E         5   2018-05-01     NO       5
# 410976                           C         3   2018-11-23     NO       0
# 3379     VISA/MASTERCARD                   7   2019-12-30    YES       2
# 1517922  VISA/MASTERCARD         C         3   2018-11-23     NO       2
# 1786043                          B        10   2019-12-30              5
# 1660846           PAYPAL         E         6   2018-05-01     NO       4
# 196235            PAYPAL         C         1   2018-10-03     NO       4
# 245695   VISA/MASTERCARD                   4   2018-07-07     NO       0
# 1969629                          B         6   2018-07-07     NO       2
# 1100406             AMEX                   3   2018-11-21     NO       1
# 1744645                          D        10   2018-04-23     NO       5
# ...                  ...       ...       ...          ...    ...     ...
# 1823357        APPLE PAY                  10   2018-01-13    YES       1
# 1703555        APPLE PAY         E         7   2018-04-24    YES       0
# 1456890           PAYPAL         B         5   2018-07-03     NO       2
# 1934808  VISA/MASTERCARD         E         4   2018-10-21    YES       1
# 1976299        APPLE PAY         D         6   2018-11-21     NO       4
# 680652            PAYPAL         A         4   2018-11-21    YES       0
# 2135844        APPLE PAY         E         7   2018-05-17    YES       4
# 1408128  VISA/MASTERCARD         A         5   2019-12-30     NO       0
# 1479219                          C         1   2018-10-21     NO       4
# 2169268        APPLE PAY         A         4   2018-05-14    YES       4
# 2024191        APPLE PAY                   3   2018-10-21     NO       4
# 710755              AMEX         D         7   2018-07-07              0
# 299991            PAYPAL         C         8   2018-05-25     NO       4
# 2159159  VISA/MASTERCARD         D         1   2018-10-07     NO       4
# 1985640             AMEX         D         6   2018-05-17    YES       4
# 1230698           PAYPAL         A         2   2018-07-20     NO       5
# 56399                            E        10   2018-02-06              2
# 1746883  VISA/MASTERCARD                   5   2018-01-10    YES       0
# 188056                           B         4   2018-05-20    YES       4
# 20009               AMEX         C         7   2018-01-13    YES       1
# 605790   VISA/MASTERCARD         D         8   2018-02-06    YES       1
# 817361         APPLE PAY         A         8   2018-05-01    YES       0
# 164565                           B         0   2019-12-30    YES       1
# 1037603                                    5   2018-11-21     NO       1
# 680629              AMEX         B         1   2018-04-23    YES       5
# 1013896  VISA/MASTERCARD         A         6   2018-03-13    YES       4
# 1646382           PAYPAL         A         1   2019-12-30     NO       0
# 1578874        APPLE PAY         B         6   2018-05-20     NO       1
# 1695111             AMEX         A         1   2018-02-13     NO       5
# 236131   VISA/MASTERCARD         A         4   2018-05-20     NO       0
#
#          TRACKNO TIMESTAMP
# 2060360   361318  05:50:52
# 754547    330635  23:41:05
# 220058    457419  20:18:53
# 1518391   335510  11:56:58
# 195986    328247  01:26:31
# 1786679   393749  13:57:21
# 1057156   433291  06:58:15
# 1481543   495862  02:08:26
# 1593234   430514  11:09:59
# 1185166   462492  05:55:03
# 1450184   347892  23:16:25
# 1481616   352566  05:55:03
# 137304    464084  09:09:58
# 1853440   303158  23:41:05
# 2071527   458895  20:18:53
# 1258012   377540  05:50:52
# 1185018   416811  07:56:56
# 1969610   301675  15:20:04
# 1899515   333680  09:09:58
# 998473    352889  01:31:40
# 410976    307349  12:16:02
# 3379      323144  12:48:46
# 1517922   490111  09:09:58
# 1786043   356306  20:16:01
# 1660846   377017  12:16:02
# 196235    315681  05:44:25
# 245695    344780  01:47:18
# 1969629   367412  11:56:58
# 1100406   376261  20:18:53
# 1744645   477644  01:45:36
# ...          ...       ...
# 1823357   350987  05:55:03
# 1703555   322939  11:09:59
# 1456890   446530  23:16:25
# 1934808   419358  05:44:25
# 1976299   312579  02:08:26
# 680652    463025  09:02:29
# 2135844   312126  06:58:15
# 1408128   382810  00:00:00
# 1479219   410801  05:56:53
# 2169268   340282  01:13:51
# 2024191   352402  00:28:54
# 710755    323823  05:50:52
# 299991    388718  07:05:34
# 2159159   354276  06:58:15
# 1985640   437608  12:50:23
# 1230698   416410  06:58:15
# 56399     462004  01:26:31
# 1746883   325573  07:02:59
# 188056    375231  12:16:02
# 20009     470215  01:45:36
# 605790    456097  02:31:39
# 817361    491116  07:56:56
# 164565    345668  00:31:21
# 1037603   343809  12:09:28
# 680629    436148  02:47:02
# 1013896   314003  10:00:05
# 1646382   403317  13:24:06
# 1578874   471712  12:25:23
# 1695111   337240  07:05:34
# 236131    464475  12:48:46
#
# [2188800 rows x 15 columns]

# %%
transactions[transactions.QTY == 0].count()
# Out:
# USERID          0
# WEBBROWSER      0
# PPC_ADD         0
# ITEM            0
# PURCHASE        0
# QTY             0
# DISCOUNT        0
# PAYMENT         0
# WAREHOUSE       0
# SHIPDAYS        0
# DELIVERYDATE    0
# REVIEW          0
# RATING          0
# TRACKNO         0
# TIMESTAMP       0
# dtype: int64

# %%
# Number count of distinct values in RATING 
transactions.RATING.value_counts()
# Out:
# 4    567549
# 0    566753
# 2    405571
# 1    324295
# 5    243629
# 3     81003
# Name: RATING, dtype: int64

# %%
transactions.RATING.value_counts(normalize = True)
# Out:
# 4    0.259297
# 0    0.258933
# 2    0.185294
# 1    0.148161
# 5    0.111307
# 3    0.037008
# Name: RATING, dtype: float64

# %% [markdown]
# #### As seen above, 25.98% of data missing in RATING

# %%
# Checking null values in dataframe 
transactions.isnull().any()
# Out:
# USERID          False
# WEBBROWSER      False
# PPC_ADD         False
# ITEM            False
# PURCHASE        False
# QTY             False
# DISCOUNT        False
# PAYMENT         False
# WAREHOUSE       False
# SHIPDAYS        False
# DELIVERYDATE    False
# REVIEW          False
# RATING          False
# TRACKNO         False
# TIMESTAMP       False
# dtype: bool

# %%
#value count by % in TIMESTAMP
transactions['TIMESTAMP'].value_counts(normalize=True)
# Out:
# 02:08:26    0.016907
# 12:25:23    0.016868
# 07:56:56    0.016816
# 05:56:53    0.016811
# 12:03:51    0.016809
# 05:44:25    0.016799
# 12:18:21    0.016786
# 10:30:09    0.016775
# 00:28:54    0.016771
# 09:42:18    0.016770
# 05:23:37    0.016755
# 00:00:00    0.016747
# 21:54:45    0.016737
# 11:56:58    0.016734
# 12:07:37    0.016728
# 21:09:24    0.016725
# 20:11:54    0.016723
# 23:16:25    0.016721
# 12:09:28    0.016717
# 12:50:23    0.016708
# 20:18:53    0.016705
# 06:16:02    0.016700
# 09:42:39    0.016699
# 13:24:06    0.016699
# 09:54:58    0.016696
# 05:50:52    0.016683
# 09:02:29    0.016668
# 12:48:46    0.016668
# 11:23:13    0.016666
# 01:47:18    0.016664
# 12:16:02    0.016662
# 11:50:25    0.016653
# 12:25:54    0.016649
# 00:03:15    0.016642
# 07:02:59    0.016641
# 07:05:34    0.016640
# 19:02:37    0.016625
# 02:47:02    0.016624
# 11:09:59    0.016624
# 01:13:51    0.016622
# 13:57:21    0.016614
# 00:44:26    0.016611
# 06:58:15    0.016606
# 09:09:58    0.016605
# 20:16:01    0.016603
# 01:45:36    0.016598
# 01:26:31    0.016596
# 02:31:39    0.016595
# 19:34:14    0.016595
# 23:07:53    0.016582
# 15:20:04    0.016559
# 00:31:21    0.016556
# 05:55:03    0.016554
# 01:18:40    0.016553
# 15:18:22    0.016546
# 23:41:05    0.016542
# 10:00:05    0.016531
# 13:09:53    0.016529
# 02:30:52    0.016527
# 01:31:40    0.016457
# Name: TIMESTAMP, dtype: float64

# %% [markdown]
# ##### As shown above, TIMESTAMP hour is within [00, 24].

# %% [markdown]
# #### Let's look at the categorical values in transactions DB

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2188800 entries, 0 to 2188799
# Data columns (total 15 columns):
# USERID          int64
# WEBBROWSER      object
# PPC_ADD         object
# ITEM            int64
# PURCHASE        object
# QTY             int64
# DISCOUNT        int64
# PAYMENT         object
# WAREHOUSE       object
# SHIPDAYS        int64
# DELIVERYDATE    datetime64[ns]
# REVIEW          object
# RATING          int64
# TRACKNO         int64
# TIMESTAMP       timedelta64[ns]
# dtypes: datetime64[ns](1), int64(7), object(6), timedelta64[ns](1)
# memory usage: 250.5+ MB

# %%
transactions.PAYMENT.value_counts()
# Out:
#                    438436
# VISA/MASTERCARD    438072
# PAYPAL             437730
# APPLE PAY          437380
# AMEX               437182
# Name: PAYMENT, dtype: int64

# %%
transactions.PAYMENT.value_counts()*100/len(transactions)
# Out:
#                    20.030885
# VISA/MASTERCARD    20.014254
# PAYPAL             19.998629
# APPLE PAY          19.982639
# AMEX               19.973593
# Name: PAYMENT, dtype: float64

# %% [markdown]
# #### As shown, 20% of missing data in PAYMENT

# %%
transactions.WAREHOUSE.unique()
# Out:
# array(['D', 'B', 'E', ' ', 'C', 'A'], dtype=object)

# %%
transactions.WAREHOUSE.value_counts()
# Out:
# A    365929
# C    365246
# D    364959
#      364427
# E    364367
# B    363872
# Name: WAREHOUSE, dtype: int64

# %%
transactions.WAREHOUSE.value_counts()*100/len(transactions)
# Out:
# A    16.718247
# C    16.687043
# D    16.673931
#      16.649625
# E    16.646884
# B    16.624269
# Name: WAREHOUSE, dtype: float64

# %% [markdown]
# ##### As seen above, 16.65% of WAREHOUSE data is missing (n=364427)

# %%
#value count TIMESTAMP (order=ascending)
transactions['TIMESTAMP'].value_counts(ascending=True)
# Out:
# 01:31:40    36021
# 02:30:52    36174
# 13:09:53    36179
# 10:00:05    36182
# 23:41:05    36208
# 15:18:22    36216
# 01:18:40    36232
# 05:55:03    36234
# 00:31:21    36237
# 15:20:04    36245
# 23:07:53    36295
# 19:34:14    36324
# 02:31:39    36324
# 01:26:31    36325
# 01:45:36    36330
# 20:16:01    36341
# 09:09:58    36346
# 06:58:15    36348
# 00:44:26    36359
# 13:57:21    36364
# 01:13:51    36383
# 11:09:59    36386
# 02:47:02    36386
# 19:02:37    36389
# 07:05:34    36422
# 07:02:59    36424
# 00:03:15    36425
# 12:25:54    36442
# 11:50:25    36450
# 12:16:02    36470
# 01:47:18    36475
# 11:23:13    36478
# 12:48:46    36482
# 09:02:29    36483
# 05:50:52    36516
# 09:54:58    36545
# 13:24:06    36550
# 09:42:39    36551
# 06:16:02    36554
# 20:18:53    36564
# 12:50:23    36571
# 12:09:28    36591
# 23:16:25    36598
# 20:11:54    36603
# 21:09:24    36607
# 12:07:37    36615
# 11:56:58    36627
# 21:54:45    36634
# 00:00:00    36655
# 05:23:37    36673
# 09:42:18    36707
# 00:28:54    36708
# 10:30:09    36718
# 12:18:21    36742
# 05:44:25    36770
# 12:03:51    36792
# 05:56:53    36795
# 07:56:56    36807
# 12:25:23    36921
# 02:08:26    37007
# Name: TIMESTAMP, dtype: int64

# %%
transactions.WEBBROWSER.unique()
# Out:
# array(['CHROME', 'EXPLORER', 'MOBILEAPP', 'SAFARI', ' '], dtype=object)

# %%
transactions['WEBBROWSER'].value_counts(normalize = True)
# Out:
# MOBILEAPP    0.399772
# CHROME       0.333050
# SAFARI       0.133532
# EXPLORER     0.066856
#              0.066791
# Name: WEBBROWSER, dtype: float64

# %%
transactions['WEBBROWSER'].value_counts(ascending = True)
# Out:
#              146192
# EXPLORER     146334
# SAFARI       292274
# CHROME       728979
# MOBILEAPP    875021
# Name: WEBBROWSER, dtype: int64

# %% [markdown]
# #### As displayed, 0.0668 % of missing data (n=146192) in WEBBROWSER.

# %%
transactions['REVIEW'].value_counts(ascending = True)
# Out:
#         219272
# YES     876310
# NO     1093218
# Name: REVIEW, dtype: int64

# %%
transactions['REVIEW'].value_counts(normalize = True)
# Out:
# NO     0.499460
# YES    0.400361
#        0.100179
# Name: REVIEW, dtype: float64

# %% [markdown]
# ##### As shown above, 10% of missing data in REVIEW (n=219,272)

# %%
transactions.PPC_ADD.value_counts()
# Out:
# KEVIN       776220
# BIANCA      465492
# ISABELLA    310562
# NO          310555
# KENZA       155264
# SENDI       155225
#              15482
# Name: PPC_ADD, dtype: int64

# %%
transactions.PPC_ADD.value_counts()*100/len(transactions)
# Out:
# KEVIN       35.463268
# BIANCA      21.266996
# ISABELLA    14.188688
# NO          14.188368
# KENZA        7.093567
# SENDI        7.091785
#              0.707328
# Name: PPC_ADD, dtype: float64

# %% [markdown]
# #### As shown, 0.7% of missing data in PPC_ADD

# %%
transactions.PURCHASE.value_counts()
# Out:
# YES    1531405
# NO      438482
#         218913
# Name: PURCHASE, dtype: int64

# %%
transactions.PURCHASE.value_counts()*100/len(transactions)
# Out:
# YES    69.965506
# NO     20.032986
#        10.001508
# Name: PURCHASE, dtype: float64

# %% [markdown]
# #### As seen above, 10% of missing data in PURCHASE (n=218913)

# %%
list(transactions.columns.values)
# Out:
# ['USERID',
#  'WEBBROWSER',
#  'PPC_ADD',
#  'ITEM',
#  'PURCHASE',
#  'QTY',
#  'DISCOUNT',
#  'PAYMENT',
#  'WAREHOUSE',
#  'SHIPDAYS',
#  'DELIVERYDATE',
#  'REVIEW',
#  'RATING',
#  'TRACKNO',
#  'TIMESTAMP']

# %%
# check duplicates
transactions.duplicated(['USERID',
 'WEBBROWSER',
 'PPC_ADD',
 'ITEM',
 'PURCHASE',
 'DISCOUNT',
 'PAYMENT',
 'WAREHOUSE',
 'SHIPDAYS',
 'DELIVERYDATE',
 'REVIEW',
 'RATING',
 'TRACKNO',
 'TIMESTAMP']).value_counts()* 100/len(transactions)
# Out:
# False    100.0
# dtype: float64

# %% [markdown]
# ### SECTION III: DATA EXPLORATION
#
# #### Part III.1.A - ITEMS

# %%
items_prep.corr()
# Out:
#                    ITEM  PURCHASEPRICE  SALEPRICE
# ITEM           1.000000      -0.003493  -0.004547
# PURCHASEPRICE -0.003493       1.000000   0.917953
# SALEPRICE     -0.004547       0.917953   1.000000
